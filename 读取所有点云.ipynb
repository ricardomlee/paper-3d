# %%
import open3d as o3d
import numpy as np
import os
import open3d_tutorial

# %%
for file in os.listdir("data/vase"):
    print(file)
    print("Load a ply point cloud, print it, and render it")
    filename="data/vase/"+file
    pcd = o3d.io.read_point_cloud(filename)
    print(pcd)
    print(np.asarray(pcd.points))
    o3d.visualization.draw_geometries([pcd])
# Out:
# cloud_view_0.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 592 points.
# [[ 1.9281569  -3.4915872  -0.7561909 ]
#  [ 2.0335426  -3.47772    -0.61704838]
#  [ 2.1120396  -3.4718473  -0.46945676]
#  ...
#  [ 2.9815464   2.6660843   0.0469149 ]
#  [ 3.0376844   2.6660392   0.19333687]
#  [ 3.2217989   2.633471    0.27858338]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x228296AE7B8>
# cloud_view_1.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 590 points.
# [[-2.3642697  3.117626   1.0660212]
#  [-2.3354397  3.1094041  1.2311203]
#  [-2.267127   3.112134   1.3802121]
#  ...
#  [-2.343122  -3.1880133  2.0917711]
#  [-2.4492979 -3.1419663  2.2906365]
#  [-2.6156926 -3.0794599  2.5022883]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43780>
# cloud_view_10.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 607 points.
# [[-1.306242   -2.7087517   1.7143511 ]
#  [-1.1567298  -2.7087176   1.7714646 ]
#  [-1.0091671  -2.6860592   1.8311106 ]
#  ...
#  [-0.22042154 -2.745837   -1.1213307 ]
#  [-0.0713747  -2.7459381  -1.0643867 ]
#  [ 0.07828368 -2.6351917  -1.0216599 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43908>
# cloud_view_11.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 604 points.
# [[-0.16365218 -2.7352695   2.2719595 ]
#  [-0.01447726 -2.7329905   2.2153099 ]
#  [ 0.13489136 -2.7176273   2.1604815 ]
#  ...
#  [ 0.00398743 -2.5502651  -0.89053094]
#  [-1.2498136  -2.7023945  -0.56541431]
#  [-1.1124499  -2.5722916  -0.63484359]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43C88>
# cloud_view_12.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 578 points.
# [[-1.4614899   2.55019    -1.0801401 ]
#  [-1.299917    2.5209959  -1.0155091 ]
#  [-1.1213458   2.4659195  -0.98284817]
#  ...
#  [-1.4490463   1.5586407   5.1859074 ]
#  [-1.2320151   1.3589618   5.1818647 ]
#  [-0.99107027  1.1244218   5.167233  ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43A20>
# cloud_view_13.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 582 points.
# [[-0.25489926  0.83329034  3.1016254 ]
#  [-0.20943218  0.63483596  3.3089235 ]
#  [-0.11666954  0.5343864   3.4631696 ]
#  ...
#  [-2.3190694  -4.4390211   0.34387922]
#  [-2.3012724  -4.593873    0.65093315]
#  [-2.2285891  -4.6557999   0.82008934]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43978>
# cloud_view_14.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 580 points.
# [[ 2.6898012  -1.1433527  -0.38322759]
#  [ 2.88486    -0.98406887 -0.38201582]
#  [ 3.0639307  -0.87026525 -0.35307235]
#  ...
#  [-0.78231537  4.0412054  -1.4315243 ]
#  [-0.51005387  4.1847162  -1.4969289 ]
#  [-0.21473503  4.3557167  -1.5954366 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43B70>
# cloud_view_15.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 580 points.
# [[-2.3677835  -2.5119281  -0.18957591]
#  [-2.2993579  -2.4369392  -0.01013994]
#  [-2.2463689  -2.344244    0.18932581]
#  ...
#  [ 3.5271311  -1.4919219  -2.261281  ]
#  [ 3.5801187  -1.2536616  -2.0249577 ]
#  [ 3.6490736  -1.0543939  -1.8098879 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43E10>
# cloud_view_16.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 580 points.
# [[-3.8290067   1.0372734  -1.8824341 ]
#  [-3.7600055   1.2502383  -2.1040356 ]
#  [-3.7063475   1.5020382  -2.3463004 ]
#  ...
#  [ 1.9927422   2.2642741   0.1235919 ]
#  [ 2.0604396   2.3455639  -0.06243765]
#  [ 2.1443582   2.4080706  -0.2280128 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA438D0>
# cloud_view_17.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 580 points.
# [[ 0.06212485 -4.4575772  -1.371938  ]
#  [ 0.23498189 -4.4015265  -1.3905532 ]
#  [ 0.52032685 -4.2421536  -1.2977155 ]
#  ...
#  [-3.1090209   0.77044535 -0.1389358 ]
#  [-2.9252844   0.90172958 -0.15299094]
#  [-2.7248163   1.0798917  -0.13750446]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43C50>
# cloud_view_18.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 577 points.
# [[ 2.0917225   4.766654    0.82482374]
#  [ 2.1206374   4.6444588   0.56529427]
#  [ 2.1374097   4.496294    0.26353955]
#  ...
#  [-0.08817518 -0.42367411  3.440093  ]
#  [-0.01620281 -0.55743814  3.2678258 ]
#  [-0.02358651 -0.84588385  3.0113168 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43DA0>
# cloud_view_19.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 577 points.
# [[ 1.0110331  -1.1283479   5.3588963 ]
#  [ 1.2553403  -1.3715742   5.3726144 ]
#  [ 1.4033377  -1.4393935   5.3199577 ]
#  ...
#  [ 1.0892863  -2.3707843  -0.75422668]
#  [ 1.2658713  -2.423512   -0.79192686]
#  [ 1.4209512  -2.4423444  -0.87045312]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43C50>
# cloud_view_2.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 457 points.
# [[-0.2901755   2.6031775   3.062614  ]
#  [-0.13729285  2.6225934   3.1454008 ]
#  [ 0.01330908  2.6230254   3.147243  ]
#  ...
#  [ 1.0010496   0.8931731   5.9525509 ]
#  [ 1.1305137   0.87000239  5.9086943 ]
#  [ 1.2666955   0.82810444  5.8293915 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA439B0>
# cloud_view_3.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 461 points.
# [[-1.3637433  -0.71645498  5.8840652 ]
#  [-1.2259641  -0.76142466  5.966506  ]
#  [-1.0973399  -0.78006107  6.0006714 ]
#  ...
#  [-0.13688271 -2.4892893   3.228802  ]
#  [ 0.01330908 -2.4800229   3.1915302 ]
#  [ 0.16543247 -2.4545941   3.0892487 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43C18>
# cloud_view_4.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 414 points.
# [[ 0.01330911 -2.503233   -1.6364613 ]
#  [ 0.16755329 -2.5605726  -1.8809521 ]
#  [-0.80009419 -2.264951   -1.326493  ]
#  ...
#  [ 0.9194864  -0.80591989 -4.5123124 ]
#  [ 1.0538477  -0.78515869 -4.4717131 ]
#  [ 1.1893698  -0.7646482  -4.4316034 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43E10>
# cloud_view_5.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 412 points.
# [[-0.29686949 -0.35140502 -2.926399  ]
#  [-0.14812715 -0.57806182 -2.5108781 ]
#  [-1.290765    0.65183604 -4.4957361 ]
#  ...
#  [ 0.33340463  2.1627414  -1.5738257 ]
#  [ 0.50680143  2.0786598  -1.2539344 ]
#  [ 0.69067192  1.9871409  -0.90574777]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43DD8>
# cloud_view_6.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 589 points.
# [[ 2.7876415  3.1538723  2.8366778]
#  [ 2.5172672  3.2489772  2.6065719]
#  [ 2.3653688  3.3100808  2.4016249]
#  ...
#  [ 2.1544619 -2.9497066  1.6595241]
#  [ 2.2487698 -2.9404113  1.5195738]
#  [ 2.2957783 -2.9433529  1.3626624]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43DA0>
# cloud_view_7.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 592 points.
# [[-3.5266953  -2.7329302   0.43890363]
#  [-3.2795496  -2.7851324   0.39250785]
#  [-3.2075481  -2.7896502   0.25598907]
#  ...
#  [-2.1779227   3.3017826  -0.34613961]
#  [-2.0970976   3.3081     -0.49232769]
#  [-1.9488235   3.3336923  -0.61549109]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43DD8>
# cloud_view_8.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 605 points.
# [[ 0.44117942  2.5077345  -1.0738933 ]
#  [ 0.5888896   2.5977545  -1.0044336 ]
#  [ 0.73623371  2.6564255  -0.93965471]
#  ...
#  [-0.20253238  2.7084098   1.9646559 ]
#  [-0.05280588  2.7458026   2.0169716 ]
#  [ 0.09630506  2.7368343   2.0750961 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43CC0>
# cloud_view_9.ply
# Load a ply point cloud, print it, and render it
# geometry::PointCloud with 603 points.
# [[-0.71471941  2.6014078  -0.95584154]
#  [-0.56092268  2.6619716  -1.0058141 ]
#  [-0.40946877  2.69976    -1.0581905 ]
#  ...
#  [ 1.3404406   2.9355886   1.3323531 ]
#  [ 0.98218542  2.6200926   1.6783687 ]
#  [ 1.1252319   2.7008214   1.6132054 ]]
# <PIL.Image.Image image mode=RGB size=1604x881 at 0x2282AA43B00>
